# %%
import json
import requests
import pandas as pd

# %%
print(value)
# Out:
# {'asset': 'USDT', 'fiat': 'RUB', 'merchantCheck': False, 'page': 1, 'payTypes': [], 'publisherType': None, 'rows': 10, 'tradeType': 'Buy'}

# %%
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Content-Length": "123",
    "content-type": "application/json",
    "Host": "p2p.binance.com",
    "Origin": "https://p2p.binance.com",
    "Pragma": "no-cache",
    "TE": "Trailers",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

value = {
  "asset": "USDT",
  "fiat": "RUB",
  "merchantCheck": False,
  "page": 1,
  "payTypes": [],
  "publisherType": "None",
  "rows": 10,
  "tradeType": "Buy"
}


r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', headers=headers, json=value)

# %%
r
# Out:
# <Response [200]>

# %%
data = r.json()

# %%
data
# Out:
# {'code': '000000',
#  'message': None,
#  'messageDetail': None,
#  'data': [{'adv': {'advNo': '11413789028580052992',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.20',
#     'initAmount': None,
#     'surplusAmount': '31.38',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '3000.00',
#     'minSingleTransAmount': '500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '1918.53',
#     'minSingleTransQuantity': '8.16',
#     'maxSingleTransQuantity': '49.01',
#     'dynamicMaxSingleTransQuantity': '31.34',
#     'tradableQuantity': '31.34',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's670441da55ca382ba2562649864e1d7a',
#     'realName': None,
#     'nickName': 'Goodprice1',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 331,
#     'monthFinishRate': 0.994,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11420262999821975552',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.21',
#     'initAmount': None,
#     'surplusAmount': '33.34',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '10000.00',
#     'minSingleTransAmount': '1000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '2038.70',
#     'minSingleTransQuantity': '16.33',
#     'maxSingleTransQuantity': '163.37',
#     'dynamicMaxSingleTransQuantity': '33.30',
#     'tradableQuantity': '33.30',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'saf4a12e709b0367b85f9d6de44050073',
#     'realName': None,
#     'nickName': 'DAS_SELLER',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 117,
#     'monthFinishRate': 0.861,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11420446446865227776',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.27',
#     'initAmount': None,
#     'surplusAmount': '251.37',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '5000.00',
#     'minSingleTransAmount': '1000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '5000.00',
#     'minSingleTransQuantity': '16.32',
#     'maxSingleTransQuantity': '81.60',
#     'dynamicMaxSingleTransQuantity': '81.60',
#     'tradableQuantity': '251.11',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'sc6462256b3953f4fbf32d51dd7bd5f84',
#     'realName': None,
#     'nickName': 'Rikohet',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 193,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11420151856071249920',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.38',
#     'initAmount': None,
#     'surplusAmount': '230.58',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '5000.00',
#     'minSingleTransAmount': '1350.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '5000.00',
#     'minSingleTransQuantity': '21.99',
#     'maxSingleTransQuantity': '81.45',
#     'dynamicMaxSingleTransQuantity': '81.45',
#     'tradableQuantity': '230.34',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's56ddce3de70637778be61b56f011cd9c',
#     'realName': None,
#     'nickName': '_AS_',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 184,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11419721954017820672',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.39',
#     'initAmount': None,
#     'surplusAmount': '1235.08',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '30000.00',
#     'minSingleTransAmount': '1000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '30000.00',
#     'minSingleTransQuantity': '16.28',
#     'maxSingleTransQuantity': '488.67',
#     'dynamicMaxSingleTransQuantity': '488.67',
#     'tradableQuantity': '1233.84',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'sa3a5876f166e3283b000717ed3e5193a',
#     'realName': None,
#     'nickName': 'solo',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 227,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11418623038034255872',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.39',
#     'initAmount': None,
#     'surplusAmount': '182.87',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '5000.00',
#     'minSingleTransAmount': '500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '5000.00',
#     'minSingleTransQuantity': '8.14',
#     'maxSingleTransQuantity': '81.44',
#     'dynamicMaxSingleTransQuantity': '81.44',
#     'tradableQuantity': '182.68',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's6ea2dbec24a636cca5beb539f79a45aa',
#     'realName': None,
#     'nickName': 'Ahma24',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 515,
#     'monthFinishRate': 0.981,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11420327628556980224',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.40',
#     'initAmount': None,
#     'surplusAmount': '142.32',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '17000.00',
#     'minSingleTransAmount': '500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '8729.71',
#     'minSingleTransQuantity': '8.14',
#     'maxSingleTransQuantity': '276.87',
#     'dynamicMaxSingleTransQuantity': '142.17',
#     'tradableQuantity': '142.17',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'sf81dcf9b8623317d839761a81fc83698',
#     'realName': None,
#     'nickName': 'MRX101',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 98,
#     'monthFinishRate': 0.943,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11419582796852928512',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.53',
#     'initAmount': None,
#     'surplusAmount': '862.55',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '40000.00',
#     'minSingleTransAmount': '10000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '40000.00',
#     'minSingleTransQuantity': '162.52',
#     'maxSingleTransQuantity': '650.08',
#     'dynamicMaxSingleTransQuantity': '650.08',
#     'tradableQuantity': '861.68',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'scb60bde7edc2333d8f3cb4cd4d5cc675',
#     'realName': None,
#     'nickName': 'crypto_yulia',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 18,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11392391829539758080',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.54',
#     'initAmount': None,
#     'surplusAmount': '716.28',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '30000.00',
#     'minSingleTransAmount': '7000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '30000.00',
#     'minSingleTransQuantity': '113.74',
#     'maxSingleTransQuantity': '487.48',
#     'dynamicMaxSingleTransQuantity': '487.48',
#     'tradableQuantity': '715.56',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'sb8b6140ba29a3365a4d8d9c98eecdfd2',
#     'realName': None,
#     'nickName': 'vittok',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 156,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11420384130949808128',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.57',
#     'initAmount': None,
#     'surplusAmount': '325.18',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '38264.00',
#     'minSingleTransAmount': '500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '20001.33',
#     'minSingleTransQuantity': '8.12',
#     'maxSingleTransQuantity': '621.47',
#     'dynamicMaxSingleTransQuantity': '324.85',
#     'tradableQuantity': '324.85',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'saf895f2057503e6a8ffb932f6f26cef7',
#     'realName': None,
#     'nickName': 'shoxrux_mirzo',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 56,
#     'monthFinishRate': 0.862,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}}],
#  'total': 460,
#  'success': True}

# %%
df = pd.DataFrame(d["adv"] for d in data["data"])

# %%
df = df.drop(['classify', 
              'advStatus', 
              'priceType', 
              'priceFloatingRatio', 
              'rateFloatingRatio', 
              'currencyRate',
             'tradeMethodCommissionRates',
              'launchCountry', 
              'abnormalStatusList',
              'closeReason', 
              'initAmount', 
              'amountAfterEditing'], axis=1)

# %%
df.head(20)
# Out:
#                   advNo tradeType asset fiatUnit  price surplusAmount  \
# 0  11413789028580052992      SELL  USDT      RUB  61.20         31.38
# 1  11420262999821975552      SELL  USDT      RUB  61.21         33.34
# 2  11420446446865227776      SELL  USDT      RUB  61.27        251.37
# 3  11420151856071249920      SELL  USDT      RUB  61.38        230.58
# 4  11419721954017820672      SELL  USDT      RUB  61.39       1235.08
# 5  11418623038034255872      SELL  USDT      RUB  61.39        182.87
# 6  11420327628556980224      SELL  USDT      RUB  61.40        142.32
# 7  11419582796852928512      SELL  USDT      RUB  61.53        862.55
# 8  11392391829539758080      SELL  USDT      RUB  61.54        716.28
# 9  11420384130949808128      SELL  USDT      RUB  61.57        325.18
#
#   maxSingleTransAmount minSingleTransAmount buyerKycLimit buyerRegDaysLimit  \
# 0              3000.00               500.00          None              None
# 1             10000.00              1000.00          None              None
# 2              5000.00              1000.00          None              None
# 3              5000.00              1350.00          None              None
# 4             30000.00              1000.00          None              None
# 5              5000.00               500.00          None              None
# 6             17000.00               500.00          None              None
# 7             40000.00             10000.00          None              None
# 8             30000.00              7000.00          None              None
# 9             38264.00               500.00          None              None
#
#    ... fiatScale priceScale fiatSymbol isTradable dynamicMaxSingleTransAmount  \
# 0  ...         2          2          ₽       True                     1918.53
# 1  ...         2          2          ₽       True                     2038.70
# 2  ...         2          2          ₽       True                     5000.00
# 3  ...         2          2          ₽       True                     5000.00
# 4  ...         2          2          ₽       True                    30000.00
# 5  ...         2          2          ₽       True                     5000.00
# 6  ...         2          2          ₽       True                     8729.71
# 7  ...         2          2          ₽       True                    40000.00
# 8  ...         2          2          ₽       True                    30000.00
# 9  ...         2          2          ₽       True                    20001.33
#
#   minSingleTransQuantity maxSingleTransQuantity dynamicMaxSingleTransQuantity  \
# 0                   8.16                  49.01                         31.34
# 1                  16.33                 163.37                         33.30
# 2                  16.32                  81.60                         81.60
# 3                  21.99                  81.45                         81.45
# 4                  16.28                 488.67                        488.67
# 5                   8.14                  81.44                         81.44
# 6                   8.14                 276.87                        142.17
# 7                 162.52                 650.08                        650.08
# 8                 113.74                 487.48                        487.48
# 9                   8.12                 621.47                        324.85
#
#   tradableQuantity commissionRate
# 0            31.34     0.00100000
# 1            33.30     0.00100000
# 2           251.11     0.00100000
# 3           230.34     0.00100000
# 4          1233.84     0.00100000
# 5           182.68     0.00100000
# 6           142.17     0.00100000
# 7           861.68     0.00100000
# 8           715.56     0.00100000
# 9           324.85     0.00100000
#
# [10 rows x 47 columns]

# %%
df.head(20)
# Out:
#                   advNo tradeType asset fiatUnit       price surplusAmount  \
# 0  11417250314189746176      SELL   BTC      RUB  1345400.00    0.01567002
# 1  11419373368655663104      SELL   BTC      RUB  1345490.00    0.00377404
# 2  11419363902859583488      SELL   BTC      RUB  1345500.00    0.03738223
# 3  11418300949872836608      SELL   BTC      RUB  1345800.00    0.00864080
# 4  11406631090376593408      SELL   BTC      RUB  1345900.00    0.01632945
# 5  11411604964437577728      SELL   BTC      RUB  1346766.13    0.46587693
# 6  11416752310207647744      SELL   BTC      RUB  1346878.00    0.04582362
# 7  11418909632830050304      SELL   BTC      RUB  1346897.00    0.23100000
# 8  11418594072299732992      SELL   BTC      RUB  1346979.00    0.03999364
# 9  11419348807233024000      SELL   BTC      RUB  1346980.00    0.03234372
#
#   maxSingleTransAmount minSingleTransAmount buyerKycLimit buyerRegDaysLimit  \
# 0             35864.00               500.00          None              None
# 1              5100.00              5000.00          None              None
# 2             50297.00             50247.00          None              None
# 3            870000.00              1000.00          None              None
# 4            870000.00              1000.00          None              None
# 5            870000.00             30000.00          None              None
# 6            870000.00             10000.00          None              None
# 7            870000.00             10000.00          None              None
# 8            777777.00               500.00          None              None
# 9            870000.00              5000.00          None              None
#
#    ... fiatScale priceScale fiatSymbol isTradable dynamicMaxSingleTransAmount  \
# 0  ...         2          2          ₽       True                    21061.37
# 1  ...         2          2          ₽       True                     5072.84
# 2  ...         2          2          ₽       True                    50247.53
# 3  ...         2          2          ₽       True                    11617.16
# 4  ...         2          2          ₽       True                    21955.84
# 5  ...         2          2          ₽       True                   626925.72
# 6  ...         2          2          ₽       True                    61669.48
# 7  ...         2          2          ₽       True                   310915.56
# 8  ...         2          2          ₽       True                    53827.53
# 9  ...         2          2          ₽       True                    43522.80
#
#   minSingleTransQuantity maxSingleTransQuantity dynamicMaxSingleTransQuantity  \
# 0             0.00037163             0.02665675                    0.01565436
# 1             0.00371611             0.00379044                    0.00377026
# 2             0.03734448             0.03738164                    0.03734488
# 3             0.00074305             0.64645563                    0.00863216
# 4             0.00074299             0.64640760                    0.01631313
# 5             0.02227558             0.64599189                    0.46550452
# 6             0.00742457             0.64593823                    0.04578699
# 7             0.00742447             0.64592912                    0.23083841
# 8             0.00037120             0.57742325                    0.03996167
# 9             0.00371200             0.64588932                    0.03231140
#
#   tradableQuantity commissionRate
# 0       0.01565436     0.00100000
# 1       0.00377026     0.00100000
# 2       0.03734488     0.00100000
# 3       0.00863216     0.00100000
# 4       0.01631313     0.00100000
# 5       0.46550452     0.00080000
# 6       0.04578699     0.00080000
# 7       0.23083841     0.00070000
# 8       0.03996167     0.00080000
# 9       0.03231140     0.00100000
#
# [10 rows x 47 columns]

# %%
df.head(20)
# Out:
#                   advNo tradeType asset fiatUnit       price surplusAmount  \
# 0  11351156930602401792      SELL   BTC      RUB  1283506.00    0.07776501
# 1  11413376865776758784      SELL   BTC      RUB  1283507.00    0.00431042
# 2  11417411996892389376      SELL   BTC      RUB  1284385.90    0.01426655
# 3  11419217260869505024      SELL   BTC      RUB  1285706.92    0.02855183
# 4  11419095318401597440      SELL   BTC      RUB  1285999.00    0.00963200
# 5  11414381958169309184      SELL   BTC      RUB  1288417.93    0.00258731
# 6  11418703234205790208      SELL   BTC      RUB  1343000.00    0.02002461
# 7  11414182029727633408      SELL   BTC      RUB  1343999.00    0.00565997
# 8  11404729384809287680      SELL   BTC      RUB  1344000.00    0.01128423
# 9  11417250314189746176      SELL   BTC      RUB  1344400.00    0.01567002
#
#   maxSingleTransAmount minSingleTransAmount buyerKycLimit buyerRegDaysLimit  \
# 0             50000.00              1500.00          None              None
# 1             21000.00               500.00          None              None
# 2            870000.00               500.00          None              None
# 3             35900.00               500.00          None              None
# 4             30000.00              1000.00          None              None
# 5            870000.00               500.00          None              None
# 6             50000.00             15000.00          None              None
# 7              2000.00               500.00          None              None
# 8             15166.00             15150.00          None              None
# 9             35864.00               500.00          None              None
#
#    ... fiatScale priceScale fiatSymbol isTradable dynamicMaxSingleTransAmount  \
# 0  ...         2          2          ₽       True                    50000.00
# 1  ...         2          2          ₽       True                     5526.92
# 2  ...         2          2          ₽       True                    18305.44
# 3  ...         2          2          ₽       True                    35900.00
# 4  ...         2          2          ₽       True                    12374.35
# 5  ...         2          2          ₽       True                     3330.19
# 6  ...         2          2          ₽       True                    26866.17
# 7  ...         2          2          ₽       True                     2000.00
# 8  ...         2          2          ₽       True                    15150.84
# 9  ...         2          2          ₽       True                    21045.72
#
#   minSingleTransQuantity maxSingleTransQuantity dynamicMaxSingleTransQuantity  \
# 0             0.00116867             0.03895579                    0.03895579
# 1             0.00038955             0.01636142                    0.00430611
# 2             0.00038929             0.67736651                    0.01425229
# 3             0.00038889             0.02792238                    0.02792238
# 4             0.00077760             0.02332816                    0.00962237
# 5             0.00038807             0.67524673                    0.00258472
# 6             0.01116902             0.03723008                    0.02000460
# 7             0.00037202             0.00148809                    0.00148809
# 8             0.01127232             0.01128422                    0.01127295
# 9             0.00037191             0.02667658                    0.01565436
#
#   tradableQuantity commissionRate
# 0       0.07770284     0.00080000
# 1       0.00430611     0.00100000
# 2       0.01425229     0.00100000
# 3       0.02852330     0.00100000
# 4       0.00962237     0.00100000
# 5       0.00258472     0.00100000
# 6       0.02000460     0.00100000
# 7       0.00565431     0.00100000
# 8       0.01127295     0.00100000
# 9       0.01565436     0.00100000
#
# [10 rows x 47 columns]

# %%
data = {
  "fiat": "RUB"
}

# %%
r = requests.post('https://p2p.binance.com/bapi/c2c/v2/public/c2c/adv/filter-conditions', json=data)

# %%
data_fiat = r.json()

# %%
data_fiat
# Out:
# {'code': '000000',
#  'message': None,
#  'messageDetail': None,
#  'data': {'countries': [{'scode': 'RU', 'name': 'Russia (Россия)'},
#    {'scode': 'BY', 'name': 'Belarus (Беларусь)'},
#    {'scode': 'KZ', 'name': 'Kazakhstan (Казахстан)'},
#    {'scode': 'AM', 'name': 'Armenia (Հայաստան)'},
#    {'scode': 'GE', 'name': 'Georgia (საქართველო)'},
#    {'scode': 'TR', 'name': 'Turkey (Türkiye)'},
#    {'scode': 'AZ', 'name': 'Azerbaijan (Azərbaycan)'}],
#   'tradeMethods': [{'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'TinkoffNew',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220826/e26c1e2b-6b35-40b4-8934-de89884ed569.png',
#     'tradeMethodName': 'Tinkoff',
#     'tradeMethodShortName': 'Tinkoff',
#     'tradeMethodBgColor': '#DAB700'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'RosBankNew',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220901/b749e0e4-8e7f-4c08-9206-a4862b4403d5.png',
#     'tradeMethodName': 'RosBank',
#     'tradeMethodShortName': 'RosBank',
#     'tradeMethodBgColor': '#EE293D'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'RaiffeisenBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220908/1aca9de4-691a-4221-bec8-c71cc16c12dc.png',
#     'tradeMethodName': 'Raiffeisenbank',
#     'tradeMethodShortName': 'Raiffeisenbank',
#     'tradeMethodBgColor': '#D89F00'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'QIWI',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200612/8f5b33f3-92a9-41c8-83ee-3e891edeb707.png',
#     'tradeMethodName': 'QIWI',
#     'tradeMethodShortName': 'QIWI',
#     'tradeMethodBgColor': '#FF8C00'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'YandexMoneyNew',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220726/2d83a83f-92c2-4715-bff5-3175dca7be7c.png',
#     'tradeMethodName': 'Юmoney',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#D89F00'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'MTSBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200616/f1669bd0-2250-4c9f-bb07-a033da130e55.png',
#     'tradeMethodName': 'MTS-Bank',
#     'tradeMethodShortName': 'MTS-Bank',
#     'tradeMethodBgColor': '#D8232A'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'HomeCreditBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210607/6e5a0961-66a6-4d61-83c3-84d2b32e5a96.png',
#     'tradeMethodName': 'Home Credit Bank (Russia)',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#C80F2E'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'PostBankNew',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220915/28042daf-df6d-4427-9996-087e6fe1fa8f.png',
#     'tradeMethodName': 'Post Bank',
#     'tradeMethodShortName': 'Post Bank',
#     'tradeMethodBgColor': '#CC003D'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'RUBfiatbalance',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20201217/e46bf11d-5e87-4099-aed6-acf4fa51904b.png',
#     'tradeMethodName': 'BinancePay (RUB)',
#     'tradeMethodShortName': 'RUB fiat balance',
#     'tradeMethodBgColor': '#D89F00'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'UralsibBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210607/d3c3cbae-a3fb-487f-b4cb-15565f8b6fb6.png',
#     'tradeMethodName': 'Uralsib Bank',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#002A63'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'Payeer',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200616/f4f0f0b9-1ba4-4a8e-9284-a30b139609e0.png',
#     'tradeMethodName': 'Payeer',
#     'tradeMethodShortName': 'Payeer',
#     'tradeMethodBgColor': '#03A9F4'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'AkBarsBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210607/ade0fa32-379c-4dd3-a1af-5f47e40ae3f0.png',
#     'tradeMethodName': 'Ak Bars Bank',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#009C32'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'Mobiletopup',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20201105/a4d4f975-3859-4763-8cfe-6e72f1c75754.png',
#     'tradeMethodName': 'Mobile top-up',
#     'tradeMethodShortName': 'Mobile top-up',
#     'tradeMethodBgColor': '#4BD63B'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'BCSBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210607/1fb03380-05ab-41fa-832c-163bd6bd14d6.png',
#     'tradeMethodName': 'BCS Bank',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#4D86EB'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'Advcash',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200825/10f7c0bb-0e68-40a5-8d26-349f5a00be4c.png',
#     'tradeMethodName': 'Advcash',
#     'tradeMethodShortName': 'Advcash',
#     'tradeMethodBgColor': '#00B27A'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'RenaissanceCredit',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210607/10793010-6a58-4414-9dd9-065b7e098a40.png',
#     'tradeMethodName': 'Renaissance Credit Bank',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#D7025F'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'RussianStandardBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200616/70a19088-9ba2-4c0b-8eab-327eef0fe6de.png',
#     'tradeMethodName': 'Russian Standard Bank',
#     'tradeMethodShortName': 'Russian Standard Bank',
#     'tradeMethodBgColor': '#83B143'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'BankSaintPetersburg',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210607/dd7b3cbf-5ea6-4359-8b33-0c4b17b677d3.png',
#     'tradeMethodName': 'Bank Saint-Petersburg',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#C41130'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'CreditEuropeBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210607/f2dafc8d-e4f5-428c-bea5-8d499b257c8a.png',
#     'tradeMethodName': 'Credit Europe Bank (Russia)',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#E2001A'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'UniCreditRussia',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200616/5aeb64c0-863a-4887-b846-889e10662848.png',
#     'tradeMethodName': 'UniCredit',
#     'tradeMethodShortName': 'UniCredit',
#     'tradeMethodBgColor': '#E2001A'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'OTPBankRussia',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200616/46203ae1-c895-4547-bfd5-0f34e1039b37.png',
#     'tradeMethodName': 'OTP',
#     'tradeMethodShortName': 'OTP',
#     'tradeMethodBgColor': '#6DB744'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'CitibankRussia',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200616/ba4364fd-d35c-4f05-89e4-f5ef003979ee.png',
#     'tradeMethodName': 'Citibank (Russia)',
#     'tradeMethodShortName': 'Citibank (Russia)',
#     'tradeMethodBgColor': '#056DAE'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'ABank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210531/f00f8bab-eefa-4276-a27a-0a66ba8c943d.png',
#     'tradeMethodName': 'A-Bank',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#78B045'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'BANK',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200612/8b6fcda1-1285-486b-ad79-07156420459d.png',
#     'tradeMethodName': 'Bank Transfer',
#     'tradeMethodShortName': 'Bank Transfer',
#     'tradeMethodBgColor': '#F0B90B'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'RaiffeisenBankAval',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210531/0cb35509-5daa-4175-88bf-8186a4fde7f5.png',
#     'tradeMethodName': 'Raiffeisen Bank Aval',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#FDF051'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'CashInPerson',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200612/4e1ada5b-88df-4594-9d80-e157e767caf1.png',
#     'tradeMethodName': 'Cash in Person',
#     'tradeMethodShortName': 'Cash in Person',
#     'tradeMethodBgColor': '#00C087'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'SpecificBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200615/f54d3282-fb38-4ff2-9cd7-cd4a808e8424.png',
#     'tradeMethodName': 'Transfers with specific bank',
#     'tradeMethodShortName': 'Transfers with specific bank',
#     'tradeMethodBgColor': '#A911CF'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'PrivatBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200615/4f1f174d-59d2-4ba7-99d6-1e454d35ef87.png',
#     'tradeMethodName': 'Privat Bank (Universal Card)',
#     'tradeMethodShortName': 'Privat Bank',
#     'tradeMethodBgColor': '#75AF26'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'AlfaBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200615/1cb5872a-482c-4974-9809-657e746040a9.png',
#     'tradeMethodName': 'Alfa-bank',
#     'tradeMethodShortName': 'Alfa-bank',
#     'tradeMethodBgColor': '#EE3424'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'CashDeposit',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200616/dcdba32a-dcd7-4d32-84a6-0616a6420240.png',
#     'tradeMethodName': 'Cash Deposit to Bank',
#     'tradeMethodShortName': 'Cash Deposit to Bank',
#     'tradeMethodBgColor': '#4E83E7'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'SBP',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20201117/f53bdaba-97d9-46bf-af61-b806be55f801.png',
#     'tradeMethodName': 'SBP - Fast Bank Transfer',
#     'tradeMethodShortName': 'SBP',
#     'tradeMethodBgColor': '#1487C9'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'Sberbank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200615/0fad2de3-f2de-4fa1-975d-792297df6fb8.png',
#     'tradeMethodName': 'Sberbank',
#     'tradeMethodShortName': 'Sberbank',
#     'tradeMethodBgColor': '#319B41'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'VTBBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200616/21f98e3d-fab2-4c6a-bec5-907d516d3409.png',
#     'tradeMethodName': 'VTB Bank',
#     'tradeMethodShortName': 'VTB Bank',
#     'tradeMethodBgColor': '#0A2973'}]},
#  'success': True}

# %%
https://p2p.binance.com/en/advertiserDetail?advertiserNo=s6a23119d5d263cdda45e75ecabe1886b

# %%
https://p2p.binance.com/en/advertiserDetail?advertiserNo=s1062226dff093735beba9a39cc1f4342

# %%
s6a23119d5d263cdda45e75ecabe1886b

# %%
s6a23119d5d263cdda45e75ecabe1886b
