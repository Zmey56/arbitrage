# %%
import json
import requests
import pandas as pd

# %%
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Content-Length": "123",
    "content-type": "application/json",
    "Host": "p2p.binance.com",
    "Origin": "https://p2p.binance.com",
    "Pragma": "no-cache",
    "TE": "Trailers",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

data = {
  "asset": "USDT",
  "fiat": "ARS",
  "page": 1,
  "rows": 10,
  "tradeType": "BUY"
}


r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', headers=headers, json=data)
print(r.text)
# Out:
# {"code":"000000","message":null,"messageDetail":null,"data":[{"adv":{"advNo":"11421164990188773376","classify":"mass","tradeType":"SELL","asset":"USDT","fiatUnit":"ARS","advStatus":null,"priceType":null,"priceFloatingRatio":null,"rateFloatingRatio":null,"currencyRate":null,"price":"287.00","initAmount":null,"surplusAmount":"869.84","amountAfterEditing":null,"maxSingleTransAmount":"287000.00","minSingleTransAmount":"800.00","buyerKycLimit":null,"buyerRegDaysLimit":null,"buyerBtcPositionLimit":null,"remarks":null,"autoReplyMsg":"","payTimeLimit":null,"tradeMethods":[{"payId":null,"payMethodId":"","payType":null,"payAccount":null,"payBank":null,"paySubBank":null,"identifier":"Wise","iconUrlColor":null,"tradeMethodName":"Wise","tradeMethodShortName":null,"tradeMethodBgColor":"#00C6FF"}],"userTradeCountFilterTime":null,"userBuyTradeCountMin":null,"userBuyTradeCountMax":null,"userSellTradeCountMin":null,"userSellTradeCountMax":null,"userAllTradeCountMin":null,"userAllTradeCountMax":null,"userTradeCompleteRateFilterTime":null,"userTradeCompleteCountMin":null,"userTradeCompleteRateMin":null,"userTradeVolumeFilterTime":null,"userTradeType":null,"userTradeVolumeMin":null,"userTradeVolumeMax":null,"userTradeVolumeAsset":null,"createTime":null,"advUpdateTime":null,"fiatVo":null,"assetVo":null,"advVisibleRet":null,"assetLogo":null,"assetScale":2,"fiatScale":2,"priceScale":2,"fiatSymbol":"ARS$","isTradable":true,"dynamicMaxSingleTransAmount":"249394.68","minSingleTransQuantity":"2.78","maxSingleTransQuantity":"1000.00","dynamicMaxSingleTransQuantity":"868.97","tradableQuantity":"868.97","commissionRate":"0.00100000","tradeMethodCommissionRates":[],"launchCountry":null,"abnormalStatusList":null,"closeReason":null},"advertiser":{"userNo":"s0e6dce556e133d2b87eeb296ab09303b","realName":null,"nickName":"bazjacb","margin":null,"marginUnit":null,"orderCount":null,"monthOrderCount":33,"monthFinishRate":0.917,"advConfirmTime":null,"email":null,"registrationTime":null,"mobile":null,"userType":"user","tagIconUrls":[],"userGrade":2,"userIdentity":"","proMerchant":null,"isBlocked":null}},{"adv":{"advNo":"11420861085417758720","classify":"profession","tradeType":"SELL","asset":"USDT","fiatUnit":"ARS","advStatus":null,"priceType":null,"priceFloatingRatio":null,"rateFloatingRatio":null,"currencyRate":null,"price":"287.00","initAmount":null,"surplusAmount":"1840.42","amountAfterEditing":null,"maxSingleTransAmount":"500000.00","minSingleTransAmount":"10000.00","buyerKycLimit":null,"buyerRegDaysLimit":null,"buyerBtcPositionLimit":null,"remarks":null,"autoReplyMsg":"","payTimeLimit":null,"tradeMethods":[{"payId":null,"payMethodId":"","payType":null,"payAccount":null,"payBank":null,"paySubBank":null,"identifier":"CashInPerson","iconUrlColor":null,"tradeMethodName":"Cash in Person","tradeMethodShortName":"Cash in Person","tradeMethodBgColor":"#00C087"}],"userTradeCountFilterTime":null,"userBuyTradeCountMin":null,"userBuyTradeCountMax":null,"userSellTradeCountMin":null,"userSellTradeCountMax":null,"userAllTradeCountMin":null,"userAllTradeCountMax":null,"userTradeCompleteRateFilterTime":null,"userTradeCompleteCountMin":null,"userTradeCompleteRateMin":null,"userTradeVolumeFilterTime":null,"userTradeType":null,"userTradeVolumeMin":null,"userTradeVolumeMax":null,"userTradeVolumeAsset":null,"createTime":null,"advUpdateTime":null,"fiatVo":null,"assetVo":null,"advVisibleRet":null,"assetLogo":null,"assetScale":2,"fiatScale":2,"priceScale":2,"fiatSymbol":"ARS$","isTradable":true,"dynamicMaxSingleTransAmount":"500000.00","minSingleTransQuantity":"34.84","maxSingleTransQuantity":"1742.16","dynamicMaxSingleTransQuantity":"1742.16","tradableQuantity":"1838.94","commissionRate":"0.00080000","tradeMethodCommissionRates":[],"launchCountry":null,"abnormalStatusList":null,"closeReason":null},"advertiser":{"userNo":"2a69ceaf35ce467798cbffa625096e30","realName":null,"nickName":"fullbrokersservices","margin":null,"marginUnit":null,"orderCount":null,"monthOrderCount":180,"monthFinishR ...

# %%
# headers = {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
#     "Cache-Control": "no-cache",
#     "Connection": "keep-alive",
#     "Content-Length": "123",
#     "content-type": "application/json",
#     "Host": "p2p.binance.com",
#     "Origin": "https://p2p.binance.com",
#     "Pragma": "no-cache",
#     "TE": "Trailers",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0"
# }

value = {
    "asset": "USDT",
    "fiat": "RUB",
    "page": 1,
    "payTypes":["TinkoffNew"],
    "rows": 10,
    "tradeType": "Buy"
}


r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', json=value)

# %%
r
# Out:
# <Response [200]>

# %%
data = r.json()

# %%
data
# Out:
# {'code': '000000',
#  'message': None,
#  'messageDetail': None,
#  'data': [{'adv': {'advNo': '11409457107542663168',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.13',
#     'initAmount': None,
#     'surplusAmount': '10000.00',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '870000.00',
#     'minSingleTransAmount': '150000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RosBankNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'RosBank',
#       'tradeMethodShortName': 'RosBank',
#       'tradeMethodBgColor': '#EE293D'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '650649.35',
#     'minSingleTransQuantity': '2303.08',
#     'maxSingleTransQuantity': '13357.89',
#     'dynamicMaxSingleTransQuantity': '9990.00',
#     'tradableQuantity': '9990.00',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's6ce0f3eb04d03222b2db1b27d5a3203f',
#     'realName': None,
#     'nickName': 'CASHG',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 334,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11421834960738983936',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.13',
#     'initAmount': None,
#     'surplusAmount': '2131.34',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '870000.00',
#     'minSingleTransAmount': '138600.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RosBankNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'RosBank',
#       'tradeMethodShortName': 'RosBank',
#       'tradeMethodBgColor': '#EE293D'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '138675.49',
#     'minSingleTransQuantity': '2128.05',
#     'maxSingleTransQuantity': '13357.89',
#     'dynamicMaxSingleTransQuantity': '2129.21',
#     'tradableQuantity': '2129.21',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's4296112c5e743a7f8da0252a29a9e4e9',
#     'realName': None,
#     'nickName': 'Pavel_777',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 35,
#     'monthFinishRate': 0.973,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11406596832777695232',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.13',
#     'initAmount': None,
#     'surplusAmount': '264.62',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '17200.00',
#     'minSingleTransAmount': '17199.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RaiffeisenBank',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Raiffeisenbank',
#       'tradeMethodShortName': 'Raiffeisenbank',
#       'tradeMethodBgColor': '#D89F00'},
#      {'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RosBankNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'RosBank',
#       'tradeMethodShortName': 'RosBank',
#       'tradeMethodBgColor': '#EE293D'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '17200.00',
#     'minSingleTransQuantity': '264.07',
#     'maxSingleTransQuantity': '264.08',
#     'dynamicMaxSingleTransQuantity': '264.08',
#     'tradableQuantity': '264.35',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's73fe3b865c2331508c215ced57ae3bf9',
#     'realName': None,
#     'nickName': 'obmen24',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 4,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11421835319345119232',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.13',
#     'initAmount': None,
#     'surplusAmount': '2302.37',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '550.00',
#     'minSingleTransAmount': '500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'TinkoffNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Tinkoff',
#       'tradeMethodShortName': 'Tinkoff',
#       'tradeMethodBgColor': '#DAB700'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '550.00',
#     'minSingleTransQuantity': '7.67',
#     'maxSingleTransQuantity': '8.44',
#     'dynamicMaxSingleTransQuantity': '8.44',
#     'tradableQuantity': '2300.06',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's415821b2bd5131a5b968528949c617af',
#     'realName': None,
#     'nickName': 'alexsank',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 2,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11401492093049405440',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.14',
#     'initAmount': None,
#     'surplusAmount': '1288.37',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '870000.00',
#     'minSingleTransAmount': '83500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RosBankNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'RosBank',
#       'tradeMethodShortName': 'RosBank',
#       'tradeMethodBgColor': '#EE293D'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '83840.58',
#     'minSingleTransQuantity': '1281.85',
#     'maxSingleTransQuantity': '13355.84',
#     'dynamicMaxSingleTransQuantity': '1287.08',
#     'tradableQuantity': '1287.08',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's84cc64a0ea703d5cbd65eae59ee74cba',
#     'realName': None,
#     'nickName': 'VIP_OBMEN_777',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 19,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11421803690764214272',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.14',
#     'initAmount': None,
#     'surplusAmount': '1307.00',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '870000.00',
#     'minSingleTransAmount': '85050.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RosBankNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'RosBank',
#       'tradeMethodShortName': 'RosBank',
#       'tradeMethodBgColor': '#EE293D'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '85052.92',
#     'minSingleTransQuantity': '1305.64',
#     'maxSingleTransQuantity': '13355.84',
#     'dynamicMaxSingleTransQuantity': '1305.69',
#     'tradableQuantity': '1305.69',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's08c84997cc2431c9885ce17d9707e0c5',
#     'realName': None,
#     'nickName': 'Nikita6031',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 20,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11421455189978038272',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.14',
#     'initAmount': None,
#     'surplusAmount': '1968.89',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '870000.00',
#     'minSingleTransAmount': '30000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RosBankNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'RosBank',
#       'tradeMethodShortName': 'RosBank',
#       'tradeMethodBgColor': '#EE293D'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '128125.36',
#     'minSingleTransQuantity': '460.54',
#     'maxSingleTransQuantity': '13355.84',
#     'dynamicMaxSingleTransQuantity': '1966.92',
#     'tradableQuantity': '1966.92',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'sf58cac4e36fb3b42946aeb615e03c7e7',
#     'realName': None,
#     'nickName': 'MoneyMagnate17',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 50,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11421190797636988928',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.14',
#     'initAmount': None,
#     'surplusAmount': '2471.87',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '200000.00',
#     'minSingleTransAmount': '30000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RosBankNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'RosBank',
#       'tradeMethodShortName': 'RosBank',
#       'tradeMethodBgColor': '#EE293D'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '160856.75',
#     'minSingleTransQuantity': '460.54',
#     'maxSingleTransQuantity': '3070.31',
#     'dynamicMaxSingleTransQuantity': '2469.40',
#     'tradableQuantity': '2469.40',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's6bb219cef9c337d09c6075e874922037',
#     'realName': None,
#     'nickName': 'Iv01',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 286,
#     'monthFinishRate': 0.944,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11420341761103171584',
#     'classify': 'profession',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.15',
#     'initAmount': None,
#     'surplusAmount': '108120.56',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '870000.00',
#     'minSingleTransAmount': '150000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RosBankNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'RosBank',
#       'tradeMethodShortName': 'RosBank',
#       'tradeMethodBgColor': '#EE293D'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '870000.00',
#     'minSingleTransQuantity': '2302.37',
#     'maxSingleTransQuantity': '13353.79',
#     'dynamicMaxSingleTransQuantity': '13353.79',
#     'tradableQuantity': '108044.92',
#     'commissionRate': '0.00070000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'se029893fb43f314ea1885b2d78db90ec',
#     'realName': None,
#     'nickName': 'Maker163',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 521,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'merchant',
#     'tagIconUrls': [],
#     'userGrade': 3,
#     'userIdentity': 'MASS_MERCHANT',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11421743463592476672',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '65.15',
#     'initAmount': None,
#     'surplusAmount': '9845.63',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '870000.00',
#     'minSingleTransAmount': '50000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RosBankNew',
#       'iconUrlColor': None,
#       'tradeMethodName': 'RosBank',
#       'tradeMethodShortName': 'RosBank',
#       'tradeMethodBgColor': '#EE293D'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '640801.99',
#     'minSingleTransQuantity': '767.45',
#     'maxSingleTransQuantity': '13353.79',
#     'dynamicMaxSingleTransQuantity': '9835.79',
#     'tradableQuantity': '9835.79',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's554c5c95513f3c66b2a0b66a6c652e24',
#     'realName': None,
#     'nickName': 'finplace',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 48,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}}],
#  'total': 328,
#  'success': True}

# %%
df = pd.DataFrame(d["adv"] for d in data["data"])

# %%
df = df.drop(['classify', 
              'advStatus', 
              'priceType', 
              'priceFloatingRatio', 
              'rateFloatingRatio', 
              'currencyRate',
             'tradeMethodCommissionRates',
              'launchCountry', 
              'abnormalStatusList',
              'closeReason', 
              'initAmount', 
              'amountAfterEditing'], axis=1)

# %%
df.head(20)
# Out:
#                   advNo tradeType asset fiatUnit   price surplusAmount  \
# 0  11325089318774292480      SELL  USDT      ARS  287.98        105.41
# 1  11419707773452083200      SELL  USDT      ARS  287.98        100.10
# 2  11416805075883016192      SELL  USDT      ARS  287.99        779.23
# 3  11376186784938205184      SELL  USDT      ARS  289.90        499.65
# 4  11225789221102362624      SELL  USDT      ARS  290.00        500.00
# 5  11420496417346310144      SELL  USDT      ARS  290.00       1939.91
# 6  11418922030877495296      SELL  USDT      ARS  292.00        193.08
# 7  11266091270010580992      SELL  USDT      ARS  293.00       2000.00
# 8  11420604000063967232      SELL  USDT      ARS  294.00      18057.85
# 9  11420739369583149056      SELL  USDT      ARS  294.00         31.25
#
#   maxSingleTransAmount minSingleTransAmount buyerKycLimit buyerRegDaysLimit  \
# 0               301.00               300.00          None              None
# 1               801.00               800.00          None              None
# 2             30000.00             10000.00          None              None
# 3           5000000.00             28700.00          None              None
# 4            500000.00            100000.00          None              None
# 5           2000000.00              1000.00          None              None
# 6               900.00               800.00          None              None
# 7            500000.00            100000.00          None              None
# 8            800000.00            100000.00          None              None
# 9            300000.00              6000.00          None              None
#
#    ... fiatScale priceScale fiatSymbol isTradable dynamicMaxSingleTransAmount  \
# 0  ...         2          2       ARS$       True                      301.00
# 1  ...         2          2       ARS$       True                      801.00
# 2  ...         2          2       ARS$       True                    30000.00
# 3  ...         2          2       ARS$       True                   144732.74
# 4  ...         2          2       ARS$       True                   144884.09
# 5  ...         2          2       ARS$       True                   562124.20
# 6  ...         2          2       ARS$       True                      900.00
# 7  ...         2          2       ARS$       True                   500000.00
# 8  ...         2          2       ARS$       True                   800000.00
# 9  ...         2          2       ARS$       True                     9178.32
#
#   minSingleTransQuantity maxSingleTransQuantity dynamicMaxSingleTransQuantity  \
# 0                   1.04                   1.04                          1.04
# 1                   2.77                   2.78                          2.78
# 2                  34.72                 104.17                        104.17
# 3                  98.99               17247.32                        499.25
# 4                 344.82                1724.13                        499.60
# 5                   3.44                6896.55                       1938.35
# 6                   2.73                   3.08                          3.08
# 7                 341.29                1706.48                       1706.48
# 8                 340.13                2721.08                       2721.08
# 9                  20.40                1020.40                         31.21
#
#   tradableQuantity commissionRate
# 0           105.32     0.00080000
# 1           100.00     0.00100000
# 2           778.60     0.00080000
# 3           499.25     0.00080000
# 4           499.60     0.00080000
# 5          1938.35     0.00080000
# 6           192.88     0.00100000
# 7          1998.40     0.00080000
# 8         18039.81     0.00100000
# 9            31.21     0.00100000
#
# [10 rows x 47 columns]

# %%
df.head(20)
# Out:
#                   advNo tradeType asset fiatUnit   price surplusAmount  \
# 0  11325089318774292480      SELL  USDT      ARS  287.98        105.41
# 1  11419707773452083200      SELL  USDT      ARS  287.98        100.10
# 2  11416805075883016192      SELL  USDT      ARS  287.99        779.23
# 3  11376186784938205184      SELL  USDT      ARS  289.90        499.65
# 4  11225789221102362624      SELL  USDT      ARS  290.00        500.00
# 5  11420496417346310144      SELL  USDT      ARS  290.00       1939.91
# 6  11418922030877495296      SELL  USDT      ARS  292.00        193.08
# 7  11266091270010580992      SELL  USDT      ARS  293.00       2000.00
# 8  11420604000063967232      SELL  USDT      ARS  294.00      18057.85
# 9  11420739369583149056      SELL  USDT      ARS  294.00         31.25
#
#   maxSingleTransAmount minSingleTransAmount buyerKycLimit buyerRegDaysLimit  \
# 0               301.00               300.00          None              None
# 1               801.00               800.00          None              None
# 2             30000.00             10000.00          None              None
# 3           5000000.00             28700.00          None              None
# 4            500000.00            100000.00          None              None
# 5           2000000.00              1000.00          None              None
# 6               900.00               800.00          None              None
# 7            500000.00            100000.00          None              None
# 8            800000.00            100000.00          None              None
# 9            300000.00              6000.00          None              None
#
#    ... fiatScale priceScale fiatSymbol isTradable dynamicMaxSingleTransAmount  \
# 0  ...         2          2       ARS$       True                      301.00
# 1  ...         2          2       ARS$       True                      801.00
# 2  ...         2          2       ARS$       True                    30000.00
# 3  ...         2          2       ARS$       True                   144732.74
# 4  ...         2          2       ARS$       True                   144884.09
# 5  ...         2          2       ARS$       True                   562124.20
# 6  ...         2          2       ARS$       True                      900.00
# 7  ...         2          2       ARS$       True                   500000.00
# 8  ...         2          2       ARS$       True                   800000.00
# 9  ...         2          2       ARS$       True                     9178.32
#
#   minSingleTransQuantity maxSingleTransQuantity dynamicMaxSingleTransQuantity  \
# 0                   1.04                   1.04                          1.04
# 1                   2.77                   2.78                          2.78
# 2                  34.72                 104.17                        104.17
# 3                  98.99               17247.32                        499.25
# 4                 344.82                1724.13                        499.60
# 5                   3.44                6896.55                       1938.35
# 6                   2.73                   3.08                          3.08
# 7                 341.29                1706.48                       1706.48
# 8                 340.13                2721.08                       2721.08
# 9                  20.40                1020.40                         31.21
#
#   tradableQuantity commissionRate
# 0           105.32     0.00080000
# 1           100.00     0.00100000
# 2           778.60     0.00080000
# 3           499.25     0.00080000
# 4           499.60     0.00080000
# 5          1938.35     0.00080000
# 6           192.88     0.00100000
# 7          1998.40     0.00080000
# 8         18039.81     0.00100000
# 9            31.21     0.00100000
#
# [10 rows x 47 columns]

# %%
df.head(20)

# %%
data = {
  "fiat": "RUB"
}

# %%
r = requests.post('https://p2p.binance.com/bapi/c2c/v2/public/c2c/adv/filter-conditions', json=data)

# %%
data_fiat = r.json()

# %%
data_fiat

# %%
https://p2p.binance.com/en/advertiserDetail?advertiserNo=s6a23119d5d263cdda45e75ecabe1886b

# %%
https://p2p.binance.com/en/advertiserDetail?advertiserNo=s1062226dff093735beba9a39cc1f4342

# %%
s6a23119d5d263cdda45e75ecabe1886b

# %%
s6a23119d5d263cdda45e75ecabe1886b
