# %%
import json
import requests
import pandas as pd

# %%
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Content-Length": "123",
    "content-type": "application/json",
    "Host": "p2p.binance.com",
    "Origin": "https://p2p.binance.com",
    "Pragma": "no-cache",
    "TE": "Trailers",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

data = {
  "asset": "USDT",
  "fiat": "ARS",
  "page": 1,
  "rows": 10,
  "tradeType": "BUY"
}


r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', headers=headers, json=data)
print(r.text)
# Out:
# {"code":"000000","message":null,"messageDetail":null,"data":[{"adv":{"advNo":"11421164990188773376","classify":"mass","tradeType":"SELL","asset":"USDT","fiatUnit":"ARS","advStatus":null,"priceType":null,"priceFloatingRatio":null,"rateFloatingRatio":null,"currencyRate":null,"price":"287.00","initAmount":null,"surplusAmount":"869.84","amountAfterEditing":null,"maxSingleTransAmount":"287000.00","minSingleTransAmount":"800.00","buyerKycLimit":null,"buyerRegDaysLimit":null,"buyerBtcPositionLimit":null,"remarks":null,"autoReplyMsg":"","payTimeLimit":null,"tradeMethods":[{"payId":null,"payMethodId":"","payType":null,"payAccount":null,"payBank":null,"paySubBank":null,"identifier":"Wise","iconUrlColor":null,"tradeMethodName":"Wise","tradeMethodShortName":null,"tradeMethodBgColor":"#00C6FF"}],"userTradeCountFilterTime":null,"userBuyTradeCountMin":null,"userBuyTradeCountMax":null,"userSellTradeCountMin":null,"userSellTradeCountMax":null,"userAllTradeCountMin":null,"userAllTradeCountMax":null,"userTradeCompleteRateFilterTime":null,"userTradeCompleteCountMin":null,"userTradeCompleteRateMin":null,"userTradeVolumeFilterTime":null,"userTradeType":null,"userTradeVolumeMin":null,"userTradeVolumeMax":null,"userTradeVolumeAsset":null,"createTime":null,"advUpdateTime":null,"fiatVo":null,"assetVo":null,"advVisibleRet":null,"assetLogo":null,"assetScale":2,"fiatScale":2,"priceScale":2,"fiatSymbol":"ARS$","isTradable":true,"dynamicMaxSingleTransAmount":"249394.68","minSingleTransQuantity":"2.78","maxSingleTransQuantity":"1000.00","dynamicMaxSingleTransQuantity":"868.97","tradableQuantity":"868.97","commissionRate":"0.00100000","tradeMethodCommissionRates":[],"launchCountry":null,"abnormalStatusList":null,"closeReason":null},"advertiser":{"userNo":"s0e6dce556e133d2b87eeb296ab09303b","realName":null,"nickName":"bazjacb","margin":null,"marginUnit":null,"orderCount":null,"monthOrderCount":33,"monthFinishRate":0.917,"advConfirmTime":null,"email":null,"registrationTime":null,"mobile":null,"userType":"user","tagIconUrls":[],"userGrade":2,"userIdentity":"","proMerchant":null,"isBlocked":null}},{"adv":{"advNo":"11420861085417758720","classify":"profession","tradeType":"SELL","asset":"USDT","fiatUnit":"ARS","advStatus":null,"priceType":null,"priceFloatingRatio":null,"rateFloatingRatio":null,"currencyRate":null,"price":"287.00","initAmount":null,"surplusAmount":"1840.42","amountAfterEditing":null,"maxSingleTransAmount":"500000.00","minSingleTransAmount":"10000.00","buyerKycLimit":null,"buyerRegDaysLimit":null,"buyerBtcPositionLimit":null,"remarks":null,"autoReplyMsg":"","payTimeLimit":null,"tradeMethods":[{"payId":null,"payMethodId":"","payType":null,"payAccount":null,"payBank":null,"paySubBank":null,"identifier":"CashInPerson","iconUrlColor":null,"tradeMethodName":"Cash in Person","tradeMethodShortName":"Cash in Person","tradeMethodBgColor":"#00C087"}],"userTradeCountFilterTime":null,"userBuyTradeCountMin":null,"userBuyTradeCountMax":null,"userSellTradeCountMin":null,"userSellTradeCountMax":null,"userAllTradeCountMin":null,"userAllTradeCountMax":null,"userTradeCompleteRateFilterTime":null,"userTradeCompleteCountMin":null,"userTradeCompleteRateMin":null,"userTradeVolumeFilterTime":null,"userTradeType":null,"userTradeVolumeMin":null,"userTradeVolumeMax":null,"userTradeVolumeAsset":null,"createTime":null,"advUpdateTime":null,"fiatVo":null,"assetVo":null,"advVisibleRet":null,"assetLogo":null,"assetScale":2,"fiatScale":2,"priceScale":2,"fiatSymbol":"ARS$","isTradable":true,"dynamicMaxSingleTransAmount":"500000.00","minSingleTransQuantity":"34.84","maxSingleTransQuantity":"1742.16","dynamicMaxSingleTransQuantity":"1742.16","tradableQuantity":"1838.94","commissionRate":"0.00080000","tradeMethodCommissionRates":[],"launchCountry":null,"abnormalStatusList":null,"closeReason":null},"advertiser":{"userNo":"2a69ceaf35ce467798cbffa625096e30","realName":null,"nickName":"fullbrokersservices","margin":null,"marginUnit":null,"orderCount":null,"monthOrderCount":180,"monthFinishR ...

# %%
# headers = {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
#     "Cache-Control": "no-cache",
#     "Connection": "keep-alive",
#     "Content-Length": "123",
#     "content-type": "application/json",
#     "Host": "p2p.binance.com",
#     "Origin": "https://p2p.binance.com",
#     "Pragma": "no-cache",
#     "TE": "Trailers",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0"
# }

value = {
    "asset": "USDT",
    "fiat": "RUB",
    "page": 1,
    "payTypes":[],
    "rows": 10,
    "tradeType": "Buy"
}


r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', json=value)

# %%
r
# Out:
# <Response [200]>

# %%
data = r.json()

# %%
data
# Out:
# {'code': '000000',
#  'message': None,
#  'messageDetail': None,
#  'data': [{'adv': {'advNo': '11420151856071249920',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.12',
#     'initAmount': None,
#     'surplusAmount': '270.64',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '5000.00',
#     'minSingleTransAmount': '1350.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '5000.00',
#     'minSingleTransQuantity': '22.08',
#     'maxSingleTransQuantity': '81.80',
#     'dynamicMaxSingleTransQuantity': '81.80',
#     'tradableQuantity': '270.36',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's56ddce3de70637778be61b56f011cd9c',
#     'realName': None,
#     'nickName': '_AS_',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 231,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11424111841236500480',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.12',
#     'initAmount': None,
#     'surplusAmount': '106.29',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '10000.00',
#     'minSingleTransAmount': '500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '6489.95',
#     'minSingleTransQuantity': '8.18',
#     'maxSingleTransQuantity': '163.61',
#     'dynamicMaxSingleTransQuantity': '106.18',
#     'tradableQuantity': '106.18',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's7e8737b4a63b3629a47138d20457f766',
#     'realName': None,
#     'nickName': '',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 1,
#     'monthFinishRate': 0.5,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11422999092805095424',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.16',
#     'initAmount': None,
#     'surplusAmount': '123.35',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '5000.00',
#     'minSingleTransAmount': '1500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '5000.00',
#     'minSingleTransQuantity': '24.52',
#     'maxSingleTransQuantity': '81.75',
#     'dynamicMaxSingleTransQuantity': '81.75',
#     'tradableQuantity': '123.22',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'sd227ea866bfc390bb4c90e6b753ec4e7',
#     'realName': None,
#     'nickName': '-Scott-',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 18,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11417027298959872000',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.19',
#     'initAmount': None,
#     'surplusAmount': '198.69',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '5000.00',
#     'minSingleTransAmount': '1000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '5000.00',
#     'minSingleTransQuantity': '16.34',
#     'maxSingleTransQuantity': '81.71',
#     'dynamicMaxSingleTransQuantity': '81.71',
#     'tradableQuantity': '198.49',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's734e79aa91a238c5b1fda6b860358d03',
#     'realName': None,
#     'nickName': 'izi_katka',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 253,
#     'monthFinishRate': 0.993,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11419582796852928512',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.20',
#     'initAmount': None,
#     'surplusAmount': '872.72',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '40000.00',
#     'minSingleTransAmount': '10000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '40000.00',
#     'minSingleTransQuantity': '163.39',
#     'maxSingleTransQuantity': '653.59',
#     'dynamicMaxSingleTransQuantity': '653.59',
#     'tradableQuantity': '871.84',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'scb60bde7edc2333d8f3cb4cd4d5cc675',
#     'realName': None,
#     'nickName': 'crypto_yulia',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 100,
#     'monthFinishRate': 0.971,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11424010685928759296',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.21',
#     'initAmount': None,
#     'surplusAmount': '760.49',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '30000.00',
#     'minSingleTransAmount': '1000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '30000.00',
#     'minSingleTransQuantity': '16.33',
#     'maxSingleTransQuantity': '490.11',
#     'dynamicMaxSingleTransQuantity': '490.11',
#     'tradableQuantity': '759.73',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 'sa3a5876f166e3283b000717ed3e5193a',
#     'realName': None,
#     'nickName': 'solo',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 273,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11421945197957820416',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.23',
#     'initAmount': None,
#     'surplusAmount': '25.95',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '6000.00',
#     'minSingleTransAmount': '500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '1587.33',
#     'minSingleTransQuantity': '8.16',
#     'maxSingleTransQuantity': '97.99',
#     'dynamicMaxSingleTransQuantity': '25.92',
#     'tradableQuantity': '25.92',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's6ea2dbec24a636cca5beb539f79a45aa',
#     'realName': None,
#     'nickName': 'Ahma24',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 602,
#     'monthFinishRate': 0.978,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11351152820062134272',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.63',
#     'initAmount': None,
#     'surplusAmount': '1345.55',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '120000.00',
#     'minSingleTransAmount': '5000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'},
#      {'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'},
#      {'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Advcash',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Advcash',
#       'tradeMethodShortName': 'Advcash',
#       'tradeMethodBgColor': '#00B27A'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '82859.95',
#     'minSingleTransQuantity': '81.12',
#     'maxSingleTransQuantity': '1947.10',
#     'dynamicMaxSingleTransQuantity': '1344.47',
#     'tradableQuantity': '1344.47',
#     'commissionRate': '0.00080000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's78f43da981dc3ca4ba65c5519f99f8cd',
#     'realName': None,
#     'nickName': 'HWOARANG',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 567,
#     'monthFinishRate': 0.98,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'merchant',
#     'tagIconUrls': [],
#     'userGrade': 3,
#     'userIdentity': 'MASS_MERCHANT',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11418502854422065152',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.63',
#     'initAmount': None,
#     'surplusAmount': '899.68',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '30000.00',
#     'minSingleTransAmount': '500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Advcash',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Advcash',
#       'tradeMethodShortName': 'Advcash',
#       'tradeMethodBgColor': '#00B27A'},
#      {'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'},
#      {'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '30000.00',
#     'minSingleTransQuantity': '8.11',
#     'maxSingleTransQuantity': '486.77',
#     'dynamicMaxSingleTransQuantity': '486.77',
#     'tradableQuantity': '898.78',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's227e041c184a3f7485e3f784f260ad39',
#     'realName': None,
#     'nickName': 'Max-Bit',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 201,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}},
#   {'adv': {'advNo': '11424060815483252736',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.64',
#     'initAmount': None,
#     'surplusAmount': '414.74',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '870000.00',
#     'minSingleTransAmount': '500.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'RUBfiatbalance',
#       'iconUrlColor': None,
#       'tradeMethodName': 'BinancePay (RUB)',
#       'tradeMethodShortName': 'RUB fiat balance',
#       'tradeMethodBgColor': '#D89F00'},
#      {'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Advcash',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Advcash',
#       'tradeMethodShortName': 'Advcash',
#       'tradeMethodBgColor': '#00B27A'},
#      {'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
#       'tradeMethodName': 'Payeer',
#       'tradeMethodShortName': 'Payeer',
#       'tradeMethodBgColor': '#03A9F4'}],
#     'userTradeCountFilterTime': None,
#     'userBuyTradeCountMin': None,
#     'userBuyTradeCountMax': None,
#     'userSellTradeCountMin': None,
#     'userSellTradeCountMax': None,
#     'userAllTradeCountMin': None,
#     'userAllTradeCountMax': None,
#     'userTradeCompleteRateFilterTime': None,
#     'userTradeCompleteCountMin': None,
#     'userTradeCompleteRateMin': None,
#     'userTradeVolumeFilterTime': None,
#     'userTradeType': None,
#     'userTradeVolumeMin': None,
#     'userTradeVolumeMax': None,
#     'userTradeVolumeAsset': None,
#     'createTime': None,
#     'advUpdateTime': None,
#     'fiatVo': None,
#     'assetVo': None,
#     'advVisibleRet': None,
#     'assetLogo': None,
#     'assetScale': 2,
#     'fiatScale': 2,
#     'priceScale': 2,
#     'fiatSymbol': '₽',
#     'isTradable': True,
#     'dynamicMaxSingleTransAmount': '25539.03',
#     'minSingleTransQuantity': '8.11',
#     'maxSingleTransQuantity': '14114.21',
#     'dynamicMaxSingleTransQuantity': '414.32',
#     'tradableQuantity': '414.32',
#     'commissionRate': '0.00100000',
#     'tradeMethodCommissionRates': [],
#     'launchCountry': None,
#     'abnormalStatusList': None,
#     'closeReason': None},
#    'advertiser': {'userNo': 's18bd3dcedfcb332c87873525243e8857',
#     'realName': None,
#     'nickName': 'P2P_Trading_',
#     'margin': None,
#     'marginUnit': None,
#     'orderCount': None,
#     'monthOrderCount': 133,
#     'monthFinishRate': 1.0,
#     'advConfirmTime': None,
#     'email': None,
#     'registrationTime': None,
#     'mobile': None,
#     'userType': 'user',
#     'tagIconUrls': [],
#     'userGrade': 2,
#     'userIdentity': '',
#     'proMerchant': None,
#     'isBlocked': None}}],
#  'total': 501,
#  'success': True}

# %%
df = pd.DataFrame(d["adv"] for d in data["data"])

# %%
df = df.drop(['classify', 
              'advStatus', 
              'priceType', 
              'priceFloatingRatio', 
              'rateFloatingRatio', 
              'currencyRate',
             'tradeMethodCommissionRates',
              'launchCountry', 
              'abnormalStatusList',
              'closeReason', 
              'initAmount', 
              'amountAfterEditing'], axis=1)

# %%
df.head(20)
# Out:
#                   advNo tradeType asset fiatUnit   price surplusAmount  \
# 0  11325089318774292480      SELL  USDT      ARS  287.98        105.41
# 1  11419707773452083200      SELL  USDT      ARS  287.98        100.10
# 2  11416805075883016192      SELL  USDT      ARS  287.99        779.23
# 3  11376186784938205184      SELL  USDT      ARS  289.90        499.65
# 4  11225789221102362624      SELL  USDT      ARS  290.00        500.00
# 5  11420496417346310144      SELL  USDT      ARS  290.00       1939.91
# 6  11418922030877495296      SELL  USDT      ARS  292.00        193.08
# 7  11266091270010580992      SELL  USDT      ARS  293.00       2000.00
# 8  11420604000063967232      SELL  USDT      ARS  294.00      18057.85
# 9  11420739369583149056      SELL  USDT      ARS  294.00         31.25
#
#   maxSingleTransAmount minSingleTransAmount buyerKycLimit buyerRegDaysLimit  \
# 0               301.00               300.00          None              None
# 1               801.00               800.00          None              None
# 2             30000.00             10000.00          None              None
# 3           5000000.00             28700.00          None              None
# 4            500000.00            100000.00          None              None
# 5           2000000.00              1000.00          None              None
# 6               900.00               800.00          None              None
# 7            500000.00            100000.00          None              None
# 8            800000.00            100000.00          None              None
# 9            300000.00              6000.00          None              None
#
#    ... fiatScale priceScale fiatSymbol isTradable dynamicMaxSingleTransAmount  \
# 0  ...         2          2       ARS$       True                      301.00
# 1  ...         2          2       ARS$       True                      801.00
# 2  ...         2          2       ARS$       True                    30000.00
# 3  ...         2          2       ARS$       True                   144732.74
# 4  ...         2          2       ARS$       True                   144884.09
# 5  ...         2          2       ARS$       True                   562124.20
# 6  ...         2          2       ARS$       True                      900.00
# 7  ...         2          2       ARS$       True                   500000.00
# 8  ...         2          2       ARS$       True                   800000.00
# 9  ...         2          2       ARS$       True                     9178.32
#
#   minSingleTransQuantity maxSingleTransQuantity dynamicMaxSingleTransQuantity  \
# 0                   1.04                   1.04                          1.04
# 1                   2.77                   2.78                          2.78
# 2                  34.72                 104.17                        104.17
# 3                  98.99               17247.32                        499.25
# 4                 344.82                1724.13                        499.60
# 5                   3.44                6896.55                       1938.35
# 6                   2.73                   3.08                          3.08
# 7                 341.29                1706.48                       1706.48
# 8                 340.13                2721.08                       2721.08
# 9                  20.40                1020.40                         31.21
#
#   tradableQuantity commissionRate
# 0           105.32     0.00080000
# 1           100.00     0.00100000
# 2           778.60     0.00080000
# 3           499.25     0.00080000
# 4           499.60     0.00080000
# 5          1938.35     0.00080000
# 6           192.88     0.00100000
# 7          1998.40     0.00080000
# 8         18039.81     0.00100000
# 9            31.21     0.00100000
#
# [10 rows x 47 columns]

# %%
df.head(20)
# Out:
#                   advNo tradeType asset fiatUnit   price surplusAmount  \
# 0  11325089318774292480      SELL  USDT      ARS  287.98        105.41
# 1  11419707773452083200      SELL  USDT      ARS  287.98        100.10
# 2  11416805075883016192      SELL  USDT      ARS  287.99        779.23
# 3  11376186784938205184      SELL  USDT      ARS  289.90        499.65
# 4  11225789221102362624      SELL  USDT      ARS  290.00        500.00
# 5  11420496417346310144      SELL  USDT      ARS  290.00       1939.91
# 6  11418922030877495296      SELL  USDT      ARS  292.00        193.08
# 7  11266091270010580992      SELL  USDT      ARS  293.00       2000.00
# 8  11420604000063967232      SELL  USDT      ARS  294.00      18057.85
# 9  11420739369583149056      SELL  USDT      ARS  294.00         31.25
#
#   maxSingleTransAmount minSingleTransAmount buyerKycLimit buyerRegDaysLimit  \
# 0               301.00               300.00          None              None
# 1               801.00               800.00          None              None
# 2             30000.00             10000.00          None              None
# 3           5000000.00             28700.00          None              None
# 4            500000.00            100000.00          None              None
# 5           2000000.00              1000.00          None              None
# 6               900.00               800.00          None              None
# 7            500000.00            100000.00          None              None
# 8            800000.00            100000.00          None              None
# 9            300000.00              6000.00          None              None
#
#    ... fiatScale priceScale fiatSymbol isTradable dynamicMaxSingleTransAmount  \
# 0  ...         2          2       ARS$       True                      301.00
# 1  ...         2          2       ARS$       True                      801.00
# 2  ...         2          2       ARS$       True                    30000.00
# 3  ...         2          2       ARS$       True                   144732.74
# 4  ...         2          2       ARS$       True                   144884.09
# 5  ...         2          2       ARS$       True                   562124.20
# 6  ...         2          2       ARS$       True                      900.00
# 7  ...         2          2       ARS$       True                   500000.00
# 8  ...         2          2       ARS$       True                   800000.00
# 9  ...         2          2       ARS$       True                     9178.32
#
#   minSingleTransQuantity maxSingleTransQuantity dynamicMaxSingleTransQuantity  \
# 0                   1.04                   1.04                          1.04
# 1                   2.77                   2.78                          2.78
# 2                  34.72                 104.17                        104.17
# 3                  98.99               17247.32                        499.25
# 4                 344.82                1724.13                        499.60
# 5                   3.44                6896.55                       1938.35
# 6                   2.73                   3.08                          3.08
# 7                 341.29                1706.48                       1706.48
# 8                 340.13                2721.08                       2721.08
# 9                  20.40                1020.40                         31.21
#
#   tradableQuantity commissionRate
# 0           105.32     0.00080000
# 1           100.00     0.00100000
# 2           778.60     0.00080000
# 3           499.25     0.00080000
# 4           499.60     0.00080000
# 5          1938.35     0.00080000
# 6           192.88     0.00100000
# 7          1998.40     0.00080000
# 8         18039.81     0.00100000
# 9            31.21     0.00100000
#
# [10 rows x 47 columns]

# %%
df.head(20)

# %%
value = {
    "fiat": "GEL",
}


r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/portal/config', json=value)

# %%
data = r.json()

# %%
data
# Out:
# {'code': '000000',
#  'message': None,
#  'messageDetail': None,
#  'data': {'fiat': 'GEL',
#   'areas': [{'area': 'EXPRESS',
#     'proMerchantFilterAvailable': False,
#     'tradeSides': [{'side': 'BUY',
#       'assets': [{'asset': 'USDT',
#         'description': 'Tether',
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191212/ec1e0b6e-06f7-4963-b454-6f631a49b4d1.png'},
#        {'asset': 'BTC',
#         'description': 'Bitcoin',
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/8fe832bb-8cd0-48a2-95ba-ebc5e9c40d4a.png'},
#        {'asset': 'BUSD',
#         'description': 'Binance USD',
#         'iconUrl': 'https://bin.bnbstatic.com/image/admin_mgs_image_upload/20200729/774f10b1-de42-45cc-a66b-bc70f0887e0d.png'},
#        {'asset': 'BNB',
#         'description': 'Binance Coin',
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/d1111da8-856d-486d-afb6-6887fd1cff78.png'},
#        {'asset': 'ETH',
#         'description': 'Ethereum',
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/766a2028-5a8e-4616-aab4-1eb5a2fa6877.png'}],
#       'convertAssets': [],
#       'tradeMethods': [{'identifier': 'BANKTRANSFERTEST'}]},
#      {'side': 'SELL',
#       'assets': [{'asset': 'USDT',
#         'description': 'Tether',
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191212/ec1e0b6e-06f7-4963-b454-6f631a49b4d1.png'},
#        {'asset': 'BTC',
#         'description': 'Bitcoin',
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/8fe832bb-8cd0-48a2-95ba-ebc5e9c40d4a.png'},
#        {'asset': 'BUSD',
#         'description': 'Binance USD',
#         'iconUrl': 'https://bin.bnbstatic.com/image/admin_mgs_image_upload/20200729/774f10b1-de42-45cc-a66b-bc70f0887e0d.png'},
#        {'asset': 'BNB',
#         'description': 'Binance Coin',
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/d1111da8-856d-486d-afb6-6887fd1cff78.png'},
#        {'asset': 'ETH',
#         'description': 'Ethereum',
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/766a2028-5a8e-4616-aab4-1eb5a2fa6877.png'}],
#       'convertAssets': [],
#       'tradeMethods': [{'identifier': 'BANKTRANSFERTEST'}]}]},
#    {'area': 'P2P',
#     'proMerchantFilterAvailable': False,
#     'tradeSides': [{'side': 'BUY',
#       'assets': [{'asset': 'USDT',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191212/ec1e0b6e-06f7-4963-b454-6f631a49b4d1.png'},
#        {'asset': 'BTC',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/8fe832bb-8cd0-48a2-95ba-ebc5e9c40d4a.png'},
#        {'asset': 'BUSD',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/image/admin_mgs_image_upload/20200729/774f10b1-de42-45cc-a66b-bc70f0887e0d.png'},
#        {'asset': 'BNB',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/d1111da8-856d-486d-afb6-6887fd1cff78.png'},
#        {'asset': 'ETH',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/766a2028-5a8e-4616-aab4-1eb5a2fa6877.png'}],
#       'convertAssets': [],
#       'tradeMethods': [{'identifier': 'BANKTRANSFERTEST'}]},
#      {'side': 'SELL',
#       'assets': [{'asset': 'USDT',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191212/ec1e0b6e-06f7-4963-b454-6f631a49b4d1.png'},
#        {'asset': 'BTC',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/8fe832bb-8cd0-48a2-95ba-ebc5e9c40d4a.png'},
#        {'asset': 'BUSD',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/image/admin_mgs_image_upload/20200729/774f10b1-de42-45cc-a66b-bc70f0887e0d.png'},
#        {'asset': 'BNB',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/d1111da8-856d-486d-afb6-6887fd1cff78.png'},
#        {'asset': 'ETH',
#         'description': None,
#         'iconUrl': 'https://bin.bnbstatic.com/images/20191211/766a2028-5a8e-4616-aab4-1eb5a2fa6877.png'}],
#       'convertAssets': [],
#       'tradeMethods': [{'identifier': 'BANKTRANSFERTEST'}]}]}],
#   'filterDefaultValues': {'publisherType': ''}},
#  'success': True}

# %%
r = requests.post('https://p2p.binance.com/bapi/c2c/v2/public/c2c/adv/filter-conditions', json=value)

# %%
data = r.json()

# %%
data
# Out:
# {'code': '000000',
#  'message': None,
#  'messageDetail': None,
#  'data': {'countries': [{'scode': 'GE', 'name': 'Georgia (საქართველო)'},
#    {'scode': 'RU', 'name': 'Russia (Россия)'}],
#   'tradeMethods': [{'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'BankofGeorgia',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210429/b6de20d9-844a-443d-9b71-05314e107481.png',
#     'tradeMethodName': 'Bank of Georgia',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#F26724'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'TBCbank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20210429/96e8e79d-8391-4dd7-b87b-6d592d665030.png',
#     'tradeMethodName': 'TBC Bank',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#00A3E0'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'CREDOBANK',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220323/def8f880-3f64-4b18-8832-1c9045a55e32.png',
#     'tradeMethodName': 'Credo Bank',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#0A68A2'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'LIBERTYBANK',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220323/da8dd665-b09f-493e-83b0-94a76f9038b1.png',
#     'tradeMethodName': 'Liberty Bank',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#000000'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'KoronaPay',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220629/e609b013-1a0b-4590-ab19-703a8495224e.png',
#     'tradeMethodName': 'KoronaPay',
#     'tradeMethodShortName': None,
#     'tradeMethodBgColor': '#FECC00'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'TinkoffNew',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220826/e26c1e2b-6b35-40b4-8934-de89884ed569.png',
#     'tradeMethodName': 'Tinkoff',
#     'tradeMethodShortName': 'Tinkoff',
#     'tradeMethodBgColor': '#DAB700'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'BANK',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200612/8b6fcda1-1285-486b-ad79-07156420459d.png',
#     'tradeMethodName': 'Bank Transfer',
#     'tradeMethodShortName': 'Bank Transfer',
#     'tradeMethodBgColor': '#F0B90B'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'WesternUnion',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200612/0cbfcaad-0132-4313-8b79-28ad1cc0026d.png',
#     'tradeMethodName': 'Western Union',
#     'tradeMethodShortName': 'Western Union',
#     'tradeMethodBgColor': '#365578'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'PrivatBank',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200615/4f1f174d-59d2-4ba7-99d6-1e454d35ef87.png',
#     'tradeMethodName': 'Privat Bank (Universal Card)',
#     'tradeMethodShortName': 'Privat Bank',
#     'tradeMethodBgColor': '#75AF26'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'RosBankNew',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20220901/b749e0e4-8e7f-4c08-9206-a4862b4403d5.png',
#     'tradeMethodName': 'RosBank',
#     'tradeMethodShortName': 'RosBank',
#     'tradeMethodBgColor': '#EE293D'},
#    {'id': None,
#     'payMethodId': '',
#     'payAccount': None,
#     'payBank': None,
#     'paySubBank': None,
#     'payType': None,
#     'identifier': 'SWIFT',
#     'iconUrlColor': '/image/admin_mgs_image_upload/20200612/ab626d2e-7aca-4b23-a704-2e153411e836.png',
#     'tradeMethodName': 'International Wire (SWIFT)',
#     'tradeMethodShortName': 'International Wire (SWIFT)',
#     'tradeMethodBgColor': '#DA7F50'}]},
#  'success': True}
