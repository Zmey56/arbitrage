# %%
import json
import requests
import pandas as pd

# %%
headers = {
    "Accept": "*/*",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
    "Cache-Control": "no-cache",
    "Connection": "keep-alive",
    "Content-Length": "123",
    "content-type": "application/json",
    "Host": "p2p.binance.com",
    "Origin": "https://p2p.binance.com",
    "Pragma": "no-cache",
    "TE": "Trailers",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0"
}

data = {
  "asset": "USDT",
  "fiat": "ARS",
  "page": 1,
  "rows": 10,
  "tradeType": "BUY"
}


r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', headers=headers, json=data)
print(r.text)
# Out:
# {"code":"000000","message":null,"messageDetail":null,"data":[{"adv":{"advNo":"11325089318774292480","classify":"profession","tradeType":"SELL","asset":"USDT","fiatUnit":"ARS","advStatus":null,"priceType":null,"priceFloatingRatio":null,"rateFloatingRatio":null,"currencyRate":null,"price":"287.98","initAmount":null,"surplusAmount":"106.45","amountAfterEditing":null,"maxSingleTransAmount":"301.00","minSingleTransAmount":"300.00","buyerKycLimit":null,"buyerRegDaysLimit":null,"buyerBtcPositionLimit":null,"remarks":null,"autoReplyMsg":"","payTimeLimit":null,"tradeMethods":[{"payId":null,"payMethodId":"","payType":null,"payAccount":null,"payBank":null,"paySubBank":null,"identifier":"CashInPerson","iconUrlColor":null,"tradeMethodName":"Cash in Person","tradeMethodShortName":"Cash in Person","tradeMethodBgColor":"#00C087"}],"userTradeCountFilterTime":null,"userBuyTradeCountMin":null,"userBuyTradeCountMax":null,"userSellTradeCountMin":null,"userSellTradeCountMax":null,"userAllTradeCountMin":nu
# ...

# %%
# headers = {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8",
#     "Cache-Control": "no-cache",
#     "Connection": "keep-alive",
#     "Content-Length": "123",
#     "content-type": "application/json",
#     "Host": "p2p.binance.com",
#     "Origin": "https://p2p.binance.com",
#     "Pragma": "no-cache",
#     "TE": "Trailers",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:88.0) Gecko/20100101 Firefox/88.0"
# }

value = {
  "asset": "USDT",
  "fiat": "RUB",
  "page": 1,
  "rows": 10,
  "tradeType": "Buy"
}


r = requests.post('https://p2p.binance.com/bapi/c2c/v2/friendly/c2c/adv/search', json=value)

# %%
r
# Out:
# <Response [200]>

# %%
data = r.json()

# %%
data
# Out:
# {'code': '000000',
#  'message': None,
#  'messageDetail': None,
#  'data': [{'adv': {'advNo': '11416378529734873088',
#     'classify': 'mass',
#     'tradeType': 'SELL',
#     'asset': 'USDT',
#     'fiatUnit': 'RUB',
#     'advStatus': None,
#     'priceType': None,
#     'priceFloatingRatio': None,
#     'rateFloatingRatio': None,
#     'currencyRate': None,
#     'price': '61.05',
#     'initAmount': None,
#     'surplusAmount': '113.44',
#     'amountAfterEditing': None,
#     'maxSingleTransAmount': '6500.00',
#     'minSingleTransAmount': '3000.00',
#     'buyerKycLimit': None,
#     'buyerRegDaysLimit': None,
#     'buyerBtcPositionLimit': None,
#     'remarks': None,
#     'autoReplyMsg': '',
#     'payTimeLimit': None,
#     'tradeMethods': [{'payId': None,
#       'payMethodId': '',
#       'payType': None,
#       'payAccount': None,
#       'payBank': None,
#       'paySubBank': None,
#       'identifier': 'Payeer',
#       'iconUrlColor': None,
# ...

# %%
df = pd.DataFrame(d["adv"] for d in data["data"])

# %%
df = df.drop(['classify', 
              'advStatus', 
              'priceType', 
              'priceFloatingRatio', 
              'rateFloatingRatio', 
              'currencyRate',
             'tradeMethodCommissionRates',
              'launchCountry', 
              'abnormalStatusList',
              'closeReason', 
              'initAmount', 
              'amountAfterEditing'], axis=1)

# %%
df.head(20)
# Out:
#                   advNo tradeType asset fiatUnit   price surplusAmount  \
# 0  11325089318774292480      SELL  USDT      ARS  287.98        105.41
# 1  11419707773452083200      SELL  USDT      ARS  287.98        100.10
# 2  11416805075883016192      SELL  USDT      ARS  287.99        779.23
# 3  11376186784938205184      SELL  USDT      ARS  289.90        499.65
# 4  11225789221102362624      SELL  USDT      ARS  290.00        500.00
# 5  11420496417346310144      SELL  USDT      ARS  290.00       1939.91
# 6  11418922030877495296      SELL  USDT      ARS  292.00        193.08
# 7  11266091270010580992      SELL  USDT      ARS  293.00       2000.00
# 8  11420604000063967232      SELL  USDT      ARS  294.00      18057.85
# 9  11420739369583149056      SELL  USDT      ARS  294.00         31.25
#
#   maxSingleTransAmount minSingleTransAmount buyerKycLimit buyerRegDaysLimit  \
# 0               301.00               300.00          None              None
# ...

# %%
df.head(20)
# Out:
#                   advNo tradeType asset fiatUnit   price surplusAmount  \
# 0  11325089318774292480      SELL  USDT      ARS  287.98        105.41
# 1  11419707773452083200      SELL  USDT      ARS  287.98        100.10
# 2  11416805075883016192      SELL  USDT      ARS  287.99        779.23
# 3  11376186784938205184      SELL  USDT      ARS  289.90        499.65
# 4  11225789221102362624      SELL  USDT      ARS  290.00        500.00
# 5  11420496417346310144      SELL  USDT      ARS  290.00       1939.91
# 6  11418922030877495296      SELL  USDT      ARS  292.00        193.08
# 7  11266091270010580992      SELL  USDT      ARS  293.00       2000.00
# 8  11420604000063967232      SELL  USDT      ARS  294.00      18057.85
# 9  11420739369583149056      SELL  USDT      ARS  294.00         31.25
#
#   maxSingleTransAmount minSingleTransAmount buyerKycLimit buyerRegDaysLimit  \
# 0               301.00               300.00          None              None
# ...

# %%
df.head(20)

# %%
data = {
  "fiat": "RUB"
}

# %%
r = requests.post('https://p2p.binance.com/bapi/c2c/v2/public/c2c/adv/filter-conditions', json=data)

# %%
data_fiat = r.json()

# %%
data_fiat

# %%
https://p2p.binance.com/en/advertiserDetail?advertiserNo=s6a23119d5d263cdda45e75ecabe1886b

# %%
https://p2p.binance.com/en/advertiserDetail?advertiserNo=s1062226dff093735beba9a39cc1f4342

# %%
s6a23119d5d263cdda45e75ecabe1886b

# %%
s6a23119d5d263cdda45e75ecabe1886b
